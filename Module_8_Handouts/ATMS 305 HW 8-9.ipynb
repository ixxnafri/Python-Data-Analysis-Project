# %% [markdown]
# # ATMS 305
# ## Homework 10: Linear regression
# ---
# ### Problem 1
#
# Perform a linear regression between hourly temperature `(DryBulbCelsius)` and dewpoint `(DewPointCelsius)` at Chicago for the month of August 2015.  Ignore missing data.
#
# (a) Make a 2-D PDF of the data, with ranges of 10 to 38 C for `DryBulbCelsius` and 6 to 24 C for `DewPointCelsius`, with bins every 1 degree C.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %pylab inline

data = pd.read_csv('chicago_hourly_aug_2015.csv', header=6)
data_plot = plt.data

#HINT: hist_2d_data=plt.hist2d( ¯\_(ツ)_/¯ )
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5847bef31e48> in <module>()
#       5
#       6 data = pd.read_csv('chicago_hourly_aug_2015.csv', header=6)
# ----> 7 data_plot = plt.data
#       8
#       9 #HINT: hist_2d_data=plt.hist2d( ¯\_(ツ)_/¯ )
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'data'

# %% [markdown]
# (a) Make a scatter plot of the data, and the linear regression fit.  Include a legend.

# %%
data
# Out:
#       WBAN      Date  Time  StationType          SkyCondition  \
# 0    94846  20150801    51           11                   CLR
# 1    94846  20150801   151           11                   CLR
# 2    94846  20150801   251           11                   CLR
# 3    94846  20150801   351           11                   CLR
# 4    94846  20150801   451           11                   CLR
# 5    94846  20150801   551           11                   CLR
# 6    94846  20150801   651           11                FEW100
# 7    94846  20150801   751           11         FEW070 FEW100
# 8    94846  20150801   851           11         SCT090 SCT150
# 9    94846  20150801   951           11         SCT095 SCT150
# 10   94846  20150801  1051           11         SCT080 SCT150
# 11   94846  20150801  1151           11  FEW060 FEW090 SCT130
# 12   94846  20150801  1251           11  SCT060 SCT090 SCT130
# 13   94846  20150801  1351           11         SCT065 SCT250
# 14   94846  20150801  1451           11         BKN070 BKN250
# 15   94846  20150801  1551           11         SCT065 BKN250
# 16   94846  20150801  1651           11         SCT060 BKN250
# 17   94846  20150801  1751           11         SCT055 BKN250
# 18   94846  20150801  1851           11         SCT055 BKN250
# 19   94846  20150801  1951           11         FEW055 BKN250
# 20   94846  20150801  2051           11                FEW250
# 21   94846  20150801  2151           11                   CLR
# 22   94846  20150801  2251           11                   CLR
# 23   94846  20150801  2351           11                   CLR
# 24   94846  20150802    51           11                SCT130
# 25   94846  20150802   151           11                FEW130
# 26   94846  20150802   251           11                FEW130
# 27   94846  20150802   351           11                SCT130
# 28   94846  20150802   451           11                SCT130
# 29   94846  20150802   551           11         FEW130 FEW350
# ..     ...       ...   ...          ...                   ...
# 839  94846  20150831   351           11                FEW002
# 840  94846  20150831   359           11                FEW001
# 841  94846  20150831   422           11                FEW001
# 842  94846  20150831   451           11                FEW001
# 843  94846  20150831   551           11         FEW001 SCT005
# 844  94846  20150831   625           11         FEW001 FEW005
# 845  94846  20150831   630           11         FEW001 FEW005
# 846  94846  20150831   632           11         FEW001 FEW005
# 847  94846  20150831   639           11         FEW001 FEW005
# 848  94846  20150831   649           11         FEW001 FEW005
# 849  94846  20150831   651           11         FEW001 FEW005
# 850  94846  20150831   725           11                   CLR
# 851  94846  20150831   751           11                FEW032
# 852  94846  20150831   810           11                FEW032
# 853  94846  20150831   851           11                   CLR
# 854  94846  20150831   951           11                   CLR
# 855  94846  20150831  1051           11                FEW032
# 856  94846  20150831  1151           11                FEW032
# 857  94846  20150831  1251           11                SCT032
# 858  94846  20150831  1351           11                SCT040
# 859  94846  20150831  1451           11                SCT042
# 860  94846  20150831  1551           11                FEW040
# 861  94846  20150831  1651           11                FEW040
# 862  94846  20150831  1751           11                FEW040
# 863  94846  20150831  1851           11                FEW050
# 864  94846  20150831  1951           11                   CLR
# 865  94846  20150831  2051           11                   CLR
# 866  94846  20150831  2151           11                   CLR
# 867  94846  20150831  2251           11                   CLR
# 868  94846  20150831  2351           11                   CLR
#
#     SkyConditionFlag  Visibility VisibilityFlag WeatherType WeatherTypeFlag  \
# 0                          10.00
# 1                          10.00
# 2                          10.00
# 3                          10.00
# 4                          10.00
# 5                          10.00
# 6                          10.00
# 7                          10.00
# 8                          10.00
# 9                          10.00
# 10                         10.00
# 11                         10.00
# 12                         10.00
# 13                         10.00
# 14                         10.00
# 15                         10.00
# 16                         10.00
# 17                         10.00
# 18                         10.00
# 19                         10.00
# 20                         10.00
# 21                         10.00
# 22                         10.00
# 23                         10.00
# 24                         10.00
# 25                         10.00
# 26                         10.00
# 27                         10.00
# 28                         10.00
# 29                         10.00
# ..               ...         ...            ...         ...             ...
# 839                         0.50                         FG
# 840                         0.25                         FG
# 841                         0.12              s          FG               s
# 842                         0.12              s          FG               s
# 843                         0.12              s          FG               s
# 844                         0.25                         FG
# 845                         1.00                         BR
# 846                         1.00                         BR
# 847                         1.50                         BR
# 848                         2.00                         BR
# 849                         2.00                         BR
# 850                         3.00                         BR
# 851                         3.00                         BR
# 852                         5.00                         BR
# 853                         8.00
# 854                        10.00
# 855                        10.00
# 856                        10.00
# 857                        10.00
# 858                        10.00
# 859                        10.00
# 860                        10.00
# 861                        10.00
# 862                        10.00
# 863                        10.00
# 864                        10.00
# 865                        10.00
# 866                         9.00
# 867                         9.00
# 868                         9.00
#
#          ...       PressureChange PressureChangeFlag  SeaLevelPressure  \
# 0        ...                                                     29.97
# 1        ...                                                     29.96
# 2        ...                                                     29.97
# 3        ...                                                     29.97
# 4        ...                                                     29.97
# 5        ...                                                     29.97
# 6        ...                                                     29.97
# 7        ...                                                     29.98
# 8        ...                                                     29.96
# 9        ...                                                     29.97
# 10       ...                                                     29.97
# 11       ...                                                     29.95
# 12       ...                                                     29.92
# 13       ...                                                     29.91
# 14       ...                                                     29.91
# 15       ...                                                     29.89
# 16       ...                                                     29.88
# 17       ...                                                     29.87
# 18       ...                                                     29.87
# 19       ...                                                     29.88
# 20       ...                                                     29.88
# 21       ...                                                     29.88
# 22       ...                                                     29.87
# 23       ...                                                     29.87
# 24       ...                                                     29.87
# 25       ...                                                     29.85
# 26       ...                                                     29.85
# 27       ...                                                     29.84
# 28       ...                                                     29.83
# 29       ...                                                     29.83
# ..       ...                  ...                ...               ...
# 839      ...                                                     30.03
# 840      ...                                                         M
# 841      ...                                                         M
# 842      ...                                                     30.04
# 843      ...                                                     30.06
# 844      ...                                                         M
# 845      ...                                                         M
# 846      ...                                                         M
# 847      ...                                                         M
# 848      ...                                                         M
# 849      ...                                                     30.06
# 850      ...                                                         M
# 851      ...                                                     30.07
# 852      ...                                                         M
# 853      ...                                                     30.07
# 854      ...                                                     30.07
# 855      ...                                                     30.06
# 856      ...                                                     30.05
# 857      ...                                                     30.03
# 858      ...                                                     30.02
# 859      ...                                                     30.00
# 860      ...                                                     29.99
# 861      ...                                                     29.99
# 862      ...                                                     29.99
# 863      ...                                                     30.00
# 864      ...                                                     30.01
# 865      ...                                                     30.02
# 866      ...                                                     30.02
# 867      ...                                                     30.03
# 868      ...                                                     30.02
#
#     SeaLevelPressureFlag  RecordType RecordTypeFlag  HourlyPrecip  \
# 0                                 AA
# 1                                 AA
# 2                                 AA
# 3                                 AA
# 4                                 AA
# 5                                 AA
# 6                                 AA
# 7                                 AA
# 8                                 AA
# 9                                 AA
# 10                                AA
# 11                                AA
# 12                                AA
# 13                                AA
# 14                                AA
# 15                                AA
# 16                                AA
# 17                                AA
# 18                                AA
# 19                                AA
# 20                                AA
# 21                                AA
# 22                                AA
# 23                                AA
# 24                                AA
# 25                                AA
# 26                                AA
# 27                                AA
# 28                                AA
# 29                                AA
# ..                   ...         ...            ...           ...
# 839                               AA
# 840                               SP
# 841                               SP
# 842                               AA
# 843                               AA
# 844                               SP
# 845                               SP
# 846                               SP
# 847                               SP
# 848                               SP
# 849                               AA
# 850                               SP
# 851                               AA
# 852                               SP
# 853                               AA
# 854                               AA
# 855                               AA
# 856                               AA
# 857                               AA
# 858                               AA
# 859                               AA
# 860                               AA
# 861                               AA
# 862                               AA
# 863                               AA
# 864                               AA
# 865                               AA
# 866                               AA
# 867                               AA
# 868                               AA
#
#     HourlyPrecipFlag  Altimeter AltimeterFlag
# 0                         29.99
# 1                         29.98
# 2                         29.98
# 3                         29.98
# 4                         29.98
# 5                         29.99
# 6                         29.99
# 7                         29.99
# 8                         29.98
# 9                         29.99
# 10                        29.98
# 11                        29.97
# 12                        29.94
# 13                        29.93
# 14                        29.92
# 15                        29.91
# 16                        29.90
# 17                        29.89
# 18                        29.89
# 19                        29.90
# 20                        29.90
# 21                        29.89
# 22                        29.89
# 23                        29.89
# 24                        29.88
# 25                        29.87
# 26                        29.86
# 27                        29.86
# 28                        29.85
# 29                        29.85
# ..               ...        ...           ...
# 839                       30.04
# 840                       30.04
# 841                       30.04
# 842                       30.05
# 843                       30.06
# 844                       30.07
# 845                       30.07
# 846                       30.07
# 847                       30.07
# 848                       30.07
# 849                       30.07
# 850                       30.08
# 851                       30.07
# 852                       30.07
# 853                       30.08
# 854                       30.08
# 855                       30.08
# 856                       30.06
# 857                       30.05
# 858                       30.03
# 859                       30.01
# 860                       30.01
# 861                       30.01
# 862                       30.01
# 863                       30.01
# 864                       30.03
# 865                       30.04
# 866                       30.03
# 867                       30.04
# 868                       30.04
#
# [869 rows x 44 columns]

# %% [markdown]
# (b) What are the fit coefficients (intercept and slope)?

# %%
# Out:
# Intercept         8.109144
# DryBulbCelsius    0.354261
# dtype: float64

# %% [markdown]
# (c) What is the 95% confidence interval of the fit?

# %%
# Out:
#                        0         1
# Intercept       6.911831  9.306457
# DryBulbCelsius  0.300409  0.408113

# %% [markdown]
# (d) Can we reject the null hypothesis that there is no relation between temperature and dewpoint (YES/NO)?  At what confidence level?

# %%
# Out:
# Intercept         7.838280e-37
# DryBulbCelsius    5.205614e-35
# dtype: float64

# %% [markdown]
# (e) What is the value of $R^2$ for this fit?

# %%
# Out:
# 0.16127092512266117

# %% [markdown]
# (f) Using your model, predict what the most likely dewpoint would be if the temperature was 40 C.

# %% [markdown]
# (g) What would the range of predictions at 40C be using the 95% confidence interval calculated in part (c)?
